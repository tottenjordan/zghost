# %% [markdown]
# # How to deploy ADK Apps to Agent Engine
#
# [Documentation link 🔗](https://google.github.io/adk-docs/deploy/agent-engine/)
#
# ## 1. Set the local environment variables
# These will be used in the Agent Engine deployment

# %%
from dotenv import load_dotenv
import os

load_dotenv("trends_and_insights_agent/.env")  # take environment variables
# Out:
# True

# %% [markdown]
# ## 2. Set up the `AdkApp` Convenience wrapper for ADK Agents -> Agent Engine
#
# Note the injection of the environment variables.

# %%
from vertexai.preview.reasoning_engines import AdkApp
from google.adk.artifacts import GcsArtifactService
from google.adk.sessions import VertexAiSessionService

from trends_and_insights_agent import agent

env_vars = {
  "GOOGLE_CLOUD_AGENT_ENGINE_ENABLE_TELEMETRY": "true",
  "OTEL_INSTRUMENTATION_GENAI_CAPTURE_MESSAGE_CONTENT": "true",
}

env_vars["GOOGLE_GENAI_USE_VERTEXAI"] = os.getenv("GOOGLE_GENAI_USE_VERTEXAI")
env_vars["BUCKET"] = os.getenv("BUCKET", "gs://default-bucket")
env_vars["GOOGLE_CLOUD_PROJECT_NUMBER"] = os.getenv("GOOGLE_CLOUD_PROJECT_NUMBER")
env_vars["YT_SECRET_MNGR_NAME"] = os.getenv("YT_SECRET_MNGR_NAME")
# env_vars["SESSION_STATE_JSON_PATH"] = os.getenv("SESSION_STATE_JSON_PATH")


my_agent = AdkApp(
    agent=agent.root_agent,
    env_vars=env_vars,
)
# Out:
# INFO:root:
#
# `SESSION_STATE_JSON_PATH`: example_state_pixel.json
#
#
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0

# %% [markdown]
# # 3. Test the Agent Engine locally

# %%
session = await my_agent.async_create_session(user_id="jwortz")
session
# Out:
# /usr/local/google/home/jwortz/zghost/.venv/lib/python3.12/site-packages/vertexai/preview/reasoning_engines/templates/adk.py:792: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   self._tmpl_attrs["credential_service"] = InMemoryCredentialService()
# /usr/local/google/home/jwortz/zghost/.venv/lib/python3.12/site-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# WARNING:google_adk.google.adk.runners:App name mismatch detected. The runner is configured with app name "default-app-name", but the root agent was loaded from "/usr/local/google/home/jwortz/zghost/.venv/lib/python3.12/site-packages/google/adk/agents", which implies app name "agents".
# WARNING:google_adk.google.adk.runners:App name mismatch detected. The runner is configured with app name "default-app-name", but the root agent was loaded from "/usr/local/google/home/jwortz/zghost/.venv/lib/python3.12/site-packages/google/adk/agents", which implies app name "agents".
# Session(id='679e6d39-8bb4-47f2-9da7-377ac853d8d9', app_name='default-app-name', user_id='jwortz', state={}, events=[], last_update_time=1764718829.917484)

# %%
await my_agent.async_list_sessions(user_id="jwortz")
# Out:
# ListSessionsResponse(sessions=[Session(id='679e6d39-8bb4-47f2-9da7-377ac853d8d9', app_name='default-app-name', user_id='jwortz', state={}, events=[], last_update_time=1764718829.917484)])

# %%
from pprint import pprint


def stream_agent(agent, prompt: str, session) -> None | Exception:
    try:
        session_id = session["id"]
    # local prefers attributes vs. remote prefers dict keys
    except TypeError:
        session_id = session.id
    except Exception as e:
        return f"Session Object not valid: {e}"

    for event in agent.stream_query(
        user_id="jwortz",
        session_id=session_id,
        message=prompt,
    ):
        pprint(event)

# %%
first_prompt = f"Hello"
stream_agent(my_agent, first_prompt, session)
# Out:
# INFO:root:
#
# Loading Initial State: {'state': {'img_artifact_keys': {'img_artifact_keys': []}, 'vid_artifact_keys': {'vid_artifact_keys': []}, 'brand': 'Google Pixel', 'target_product': 'Pixel 9 smartphone', 'target_audience': ['Demographics: millennials who follow jam bands such as Widespread Panic and Phish.', 'Psychographics: millennials who respond positively to nostalgic messages.', 'Lifestyle or profession: frequent travelers; spending most income on concert experiences.', 'Hobbies, interests, humor: music lovers, attend lots of jam band concerts.', 'Actively researching concert and music festival tickets; musical instruments.'], 'key_selling_points': ['Best Take - Group pics, perfected. Pixel’s Best Take combines similar photos into one fantastic picture where everyone looks their best. AI is able to blend multiple still images to give everyone their best look', "Night Sight + Astrophotography - Capture the cosmos with Pixel’s signature 'Night Sight' feature. 'Night Sight' helps capture everything from the city lights to starry skies in the dark with Astrophotography.", "Magic Editor - Magic Editor with Pixel lets you use generative AI to reimagine your photos. Remove distractions, improve background, and more. It's an intuitive new way to edit, so you're in control of your images, whether you want to better capture the moment or add your own creative touch. ", 'Call Screen - Goodbye, spam calls. With Call Screen, Pixel can now detect and filter out even more spam calls. For other calls, it can tell you who’s calling and why before you pick up. Detect and decline spam calls without distracting you.', 'Live Translate - Live Translate enables real-time translation without an app and without an internet connection - not just text-based but also spoken words, interpreting live audio from one speaker to another. You can read text in another language by pointing the camera at a sign or a menu, or watch a video that isn’t in your native tongue with Live Caption. ', 'Real Tone - this feature represents the nuances of more skin tones beautifully, authentically, and accurately in photos and video, with improvements for low light scenarios as well.'], 'target_search_trends': {'target_search_trends': []}, 'target_yt_trends': {'target_yt_trends': []}}}
#
#
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {'_state_init': True,
#                              'brand': 'Google Pixel',
#                              'gcs_folder': '2025_12_02_23_25',
#                              'img_artifact_keys': {'img_artifact_keys': []},
#                              'key_selling_points': ['Best Take - Group pics, '
#                                                     'perfected. Pixel’s Best '
#                                                     'Take combines similar '
#                                                     'photos into one fantastic '
#                                                     'picture where everyone '
#                                                     'looks their best. AI is '
#                                                     'able to blend multiple '
#                                                     'still images to give '
#                                                     'everyone their best look',
#                                                     'Night Sight + '
#                                                     'Astrophotography - '
#                                                     'Capture the cosmos with '
#                                                     "Pixel’s signature 'Night "
#                                                     "Sight' feature. 'Night "
#                                                     "Sight' helps capture "
#                                                     'everything from the city '
#                                                     'lights to starry skies in '
#                                                     'the dark with '
#                                                     'Astrophotography.',
#                                                     'Magic Editor - Magic '
#                                                     'Editor with Pixel lets '
#                                                     'you use generative AI to '
#                                                     'reimagine your photos. '
#                                                     'Remove distractions, '
#                                                     'improve background, and '
#                                                     "more. It's an intuitive "
#                                                     'new way to edit, so '
#                                                     "you're in control of your "
#                                                     'images, whether you want '
#                                                     'to better capture the '
#                                                     'moment or add your own '
#                                                     'creative touch. ',
#                                                     'Call Screen - Goodbye, '
#                                                     'spam calls. With Call '
#                                                     'Screen, Pixel can now '
#                                                     'detect and filter out '
#                                                     'even more spam calls. For '
#                                                     'other calls, it can tell '
#                                                     'you who’s calling and why '
#                                                     'before you pick up. '
#                                                     'Detect and decline spam '
#                                                     'calls without distracting '
#                                                     'you.',
#                                                     'Live Translate - Live '
#                                                     'Translate enables '
#                                                     'real-time translation '
#                                                     'without an app and '
#                                                     'without an internet '
#                                                     'connection - not just '
#                                                     'text-based but also '
#                                                     'spoken words, '
#                                                     'interpreting live audio '
#                                                     'from one speaker to '
#                                                     'another. You can read '
#                                                     'text in another language '
#                                                     'by pointing the camera at '
#                                                     'a sign or a menu, or '
#                                                     'watch a video that isn’t '
#                                                     'in your native tongue '
#                                                     'with Live Caption. ',
#                                                     'Real Tone - this feature '
#                                                     'represents the nuances of '
#                                                     'more skin tones '
#                                                     'beautifully, '
#                                                     'authentically, and '
#                                                     'accurately in photos and '
#                                                     'video, with improvements '
#                                                     'for low light scenarios '
#                                                     'as well.'],
#                              'target_audience': ['Demographics: millennials '
#                                                  'who follow jam bands such as '
#                                                  'Widespread Panic and Phish.',
#                                                  'Psychographics: millennials '
#                                                  'who respond positively to '
#                                                  'nostalgic messages.',
#                                                  'Lifestyle or profession: '
#                                                  'frequent travelers; spending '
#                                                  'most income on concert '
#                                                  'experiences.',
#                                                  'Hobbies, interests, humor: '
#                                                  'music lovers, attend lots of '
#                                                  'jam band concerts.',
#                                                  'Actively researching concert '
#                                                  'and music festival tickets; '
#                                                  'musical instruments.'],
#                              'target_product': 'Pixel 9 smartphone',
#                              'target_search_trends': {'target_search_trends': []},
#                              'target_yt_trends': {'target_yt_trends': []},
#                              'vid_artifact_keys': {'vid_artifact_keys': []}}},
#  'author': 'root_agent',
#  'id': '82aefb96-367d-4073-abde-e9044488537b',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'timestamp': 1764717934.519455}
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {'request_count': 1,
#                              'timer_start': 1764717934.5281775}},
#  'author': 'root_agent',
#  'avg_logprobs': -0.1504828424164743,
#  'content': {'parts': [{'text': "Hello! I'm your Expert AI Marketing Research "
#                                 '& Strategy Assistant. I can help you with '
#                                 'comprehensive insights, trend analysis, and '
#                                 'creative ideas for your marketing campaigns.\n'
#                                 '\n'
#                                 "Let's start by gathering some information "
#                                 'about your campaign and exploring interesting '
#                                 'trends.\n',
#                         'thought_signature': 'Cp4CAePx_148PBN3CjqiTzOyZJfAkLn3mvSHZbOOpl33HZ0_ZpVs3_2BS4hyFXbV0UKytay98rtfzI5rGa6sISvjGXFfGWOPMYUT6MkFKU4PhpZPtqJ4WhZax86yShFCLQSKcOA4qC3FSiAN9-HXwpuHxhoy7kCW_UNlLxhjX1SFus5REXZrbR0_Y33cLN1SuOZZcEM7eU9ONs6zoxEAGOSpAYa1PiHSHe3kp0szpSWWtLsNBgmf54GDHrIhDKOMPiJRC0rg1U596zSBnVOSFRF64zLXqRtv_594wiHPlPOUpsfmtQneYSh4gubTWVOOrhGyfbx0hCPAbnP-J2pzn7ucoq7omMHen8SbuyeR2fQxprA3Dd6WkiGkMmu_HM85Lg=='},
#                        {'function_call': {'args': {'agent_name': 'trends_and_insights_agent'},
#                                           'id': 'adk-1804bb3a-28b4-40ae-b7b2-cd6f39259964',
#                                           'name': 'transfer_to_agent'}}],
#              'role': 'model'},
#  'finish_reason': 'STOP',
#  'id': '807fe4b8-a5e7-49d8-8dcb-2981cfe4e0c3',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'long_running_tool_ids': [],
#  'model_version': 'gemini-2.5-flash',
#  'timestamp': 1764717934.528121,
#  'usage_metadata': {'candidates_token_count': 66,
#                     'candidates_tokens_details': [{'modality': 'TEXT',
#                                                    'token_count': 66}],
#                     'prompt_token_count': 1353,
#                     'prompt_tokens_details': [{'modality': 'TEXT',
#                                                'token_count': 1353}],
#                     'thoughts_token_count': 61,
#                     'total_token_count': 1480,
#                     'traffic_type': 'ON_DEMAND'}}
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {},
#              'transfer_to_agent': 'trends_and_insights_agent'},
#  'author': 'root_agent',
#  'content': {'parts': [{'function_response': {'id': 'adk-1804bb3a-28b4-40ae-b7b2-cd6f39259964',
#                                               'name': 'transfer_to_agent',
#                                               'response': {'result': None}}}],
#              'role': 'user'},
#  'id': '6b979e0f-d759-4fee-b1b3-7fd6991c0cbc',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'timestamp': 1764717936.283009}
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {}},
#  'author': 'trends_and_insights_agent',
#  'avg_logprobs': -4.400714874267578,
#  'content': {'parts': [{'function_call': {'args': {'key': 'brand',
#                                                    'value': 'Google Pixel'},
#                                           'id': 'adk-f722a53b-b9f3-4017-aff6-6215331547b8',
#                                           'name': 'memorize'},
#                         'thought_signature': 'CvsTAePx_15LRjeIb_bFxbEhIHEMglj3M0RwtKsRVeHjqridUZdC0Y3LBbTdOhisDfv8yBb53yZFU0NVV5mqh3PrJ-_5qgI3gce7kvrMpJmHsfjs_1aJeZb1hrnWPPwweRk3y1_FHuvc4Iv5lh-isu9yKPfv77zzGJg8WQQ-OlH8LCrCYsMd1dDvAbB0EuNj8lKUPEF8g6gxG61D5GO69iPIoA1I97bxqRHT6auIi8eQOWswv5FrR16aHQs6KpOW4Wxjh0kFGfAFEHgsLfzvhsMR4ta6j17jiZSmAPAzDjrcvIKbVZli3PuJRYrwTIj8GYFIhEnTLYeXDMW6cwkgBPcYARFfrdvGLHiQSEOyX-9Q-oy7603715Ggoap6ZFAplikkRUPpxqM6XrJIFWzfbz_5f_tQFOoT2-Db9s0VHy-NpfsVq7f-e-nb_swleGYRiV40Zd-hPPlW36veu-4K-iLnNSP3eme2LSzl9FaRaueQPww26Ozi8mlJy-RcE2rLmXatSR20_TdCsCxE2-PnPcbYN2OYL1C1CZvDYFY_hqFxcEZdkI6TIXXgcaAH-RqvrKb6BSf1-PBkOSUPhkYWI1ZCz53IE1RPSU_ly9x7taLcGqw2DnUheoOXUN_m8s2cHKzMomgV0vfGJ7G1CxTL7yMoVK7Hex4QW3uJ7YGA43DsPMwkn6IbbrOYOLcEw5_dxKvzZ83rStory0QIGDUeCQcxJSxjfgKmPxIr9zS-ZrLyc7QV68XGm_hRR1scXDoAx5PY1qWJHF3vnrZ2Os4wlv36OVNJx97cPls9QR_CL_snYLNT95BUpxjOBygleCVhJZu-gny4eGoT8YSkA68C-TU_NUCaiZzgwktBdQU4MWQle39bnLwrlasyT5vQSJITJNZBnvstEkE1lTcAejKRFHmk4rOlCvelTZmeFBSvq4sTtnVUXc3aHJ-7I2gzS2WeIoDrW-hEszszgy5gw644jJ7dxDBQhUQYe0giLDHodf8FJe6Vp_qLr_5Dnyssb6cV_lqIYm17EUcmBMhyR3HpA962AaTFejRRD7IJRZEQ2NaXdNkDWo8qvI0Ouxpkrvp8lOl7Rw4jppJbtur7T8BkoCTa302Bw_Ur_7INdOBio7eBSLZMRXbza5ClslruHbPPQvMQMKgVJBOycpYhIYJMgOXAM4y-GfwU8FIpkZxsSTbmDHcCM-Pazpeg7NrzCtOJPekuKMGnrNdetBFq-U8-NT3NTR6XgvElaZPjf336YY9e8axBMscT1j5P-epy8QeIHoV7RXFoj0_ljMDCajwTem-_KtKxDGQSockjPDdiygUWRUu__qfYNiXkHvmCdm7yyYEkGEIbvlgJxRLS-fbt1F5QVb3jh4TpIo90jQmTUNqqXfrq2PdYRKFZP-9QmdqOoDLuHeVQcXRt_giDs3H_G-XCcI-xAe0GrfOu9hdaWLAoL0bp5S7OMxBtvECdaM8bT1clT492M_1VV6sKabKF61KOSpGLPeLWXhKyhSX3X-L-Ce7L5RszuNC2kUd8pC7M2ByNhkp76BlX43da4ChYfa2NOs14Jv4Gnu186_3CIR53C0A9pqHqDFgK1NCxhTvS3yNTHVHBvuga10GnO6G4yq1Fetu6Ki4b8T0zmtL7Sy4f9vrx4PpY2PUh9jsxRSCpNBzQh1Xfl6kvdUoqffUWRDxEOpa2bD3_ikOsr_gvTZGZBvgLUW1vgTko-s_rYgU7KFah7UXyc851-9eCITLYrZCPetXorfSksqG0PoNAIqVJSZz_W53kiQMNS4cMs5zYsPmMO6JQpBztVjGwFBVVJKXZLhKfcdpsMi_ljDpt2VXuLDiHX_hBNK8Q6swV_DaYzlzK1auUi8sXbqPW2Z4IlnBtUIj-RDpFNRyIvjd3trTQJ73kDkKtBV0kiJAra9mCWDZIFNkx8I7Y3RWulCUyoczQC2PC44sRCQSTEvntiljn1MxCgTED16QC0qMKDvl8JBpq33miQulRs350tC6I9HLrxbMVflPC1_NRdDyo1RP71DOtB--4q8pTw0hc8Y25kA4IgIB7ValukwhwxdaQwVTLgN6KAxIq8gdMM_HdjkV2kEHh0GGPhswzl74npsvex99pqLYOB3-vpyW_W222YttnMiJpeHUzfrX9De0u_kb0Q6QOu70o1YQhz_bMdmPXlwReeMaBiuUW8reRYXkWED0twDsDo7itZkv2hWOXFafvcV7VqD_O5yGcyUdWEnKjWF2BB8N_0DRJMqwlj1QgVGNWzmyK1y94-FqIpM-lK0ueoEjUl3r3pONHnl9F0jRR7QpGySWVeeiZNMhJX0qmwsHwp6XReMPWkeGMkkg5Av7gWBDTvkM_iEDE53SvOV6kCY0pyZnlKc4WhPdlct9aWrCLAlfu0_4RM_XnHgoYmW1kzUrKLCLLnZeJuqHjAzcF-3a4zY0MnLwnPfTpjNHDdbtXI5xLKJ9Vsoh6WYcq_ko3bouWnvkpZy3cBxPXoWyXI1X9QAAA56V-u8ZXFSbkW1GmICwk5xShJVXyC3YUQahhYREYtWAuGvJB7f-P0yZxtZvNKn9Tg_uSUGB3vmrI7IPJP0H62HWS1wWk711eiwMv84BPYLs8aWmbXhdbQEppHQZqtNkGgbrGS1EzCxI6Y8JrNCzPSUbp8X0cznHAQ60LFHq7RVZrDaGvRxcrSB7plXXcKhpfeBAfmxiVcMhNwiYouBlIJBs3yLoHE80_5Cid42-hd82G7fKx57RP9syYQLVRc5bOYhsABBfK3MtLQDxNwDd7G53zFXDqMwltt9rcnB45oCalNXKu_Mc6qhoEfBeMiWdynnVUKBsGcpLLpOiNictbK4Z83RLj0cxOPqJ36D-y2SjELdutiNzD4WsTerDuQxWkrlVwI-Y_4Cx_u9UxbFb6DdXMBPgxME5MFVptZXCgBwBewsR53sHEAmdNG6Px1pqaWJlF7Un1GZhk4x5Zkgp47nb2R4bxlq0TBXL5cGe5kp-4lr1sthLjiTTuB2vuJKLCm1JoFy0sp0efTumt3ZPJdGkvtqrq4obRxNxtoyVOEGOL5UV8L_P00U5dcc2Zgc4EvaXtsgHoMMb3SIOZvwdlQgGvDgBaoANdgah5laWI0cpyMnTghSJal6AXLKEjSMjcK9N9IxspSal-I4MYFc436Z3C4LuriLAkjUJKjwj9E3A2835eA4r8z4QYhkWswqXsxg4dOcFh3poAKskXw8Y5ocLlgQwrJpxqafE0hfseqOkw2-Gc_ST8VIn8_gMsuHxZymgUg-KVCULk2Dsc9YrqbFSsiu5C32Y01028Q7ADF7J-_m9aDWDmGoqiYq6ptlW2fjGkdiUqR9_U2-gDCvexSI-w5L4N1dOP7zcHAdL8sWgzdC-b8JVqprdoBC4ZRlI3vutaDGdxFTU='}],
#              'role': 'model'},
#  'finish_reason': 'STOP',
#  'id': '0b57f6db-f491-47b5-8352-b02f6c484407',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'long_running_tool_ids': [],
#  'model_version': 'gemini-2.5-flash',
#  'timestamp': 1764717936.285507,
#  'usage_metadata': {'candidates_token_count': 7,
#                     'candidates_tokens_details': [{'modality': 'TEXT',
#                                                    'token_count': 7}],
#                     'prompt_token_count': 2630,
#                     'prompt_tokens_details': [{'modality': 'TEXT',
#                                                'token_count': 2630}],
#                     'thoughts_token_count': 538,
#                     'total_token_count': 3175,
#                     'traffic_type': 'ON_DEMAND'}}
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {'brand': 'Google Pixel'}},
#  'author': 'trends_and_insights_agent',
#  'content': {'parts': [{'function_response': {'id': 'adk-f722a53b-b9f3-4017-aff6-6215331547b8',
#                                               'name': 'memorize',
#                                               'response': {'status': 'Stored '
#                                                                      '"brand": '
#                                                                      '"Google '
#                                                                      'Pixel"'}}}],
#              'role': 'user'},
#  'id': 'af9056a9-92bc-4c29-a7b8-f1c3d6322fb3',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'timestamp': 1764717939.489645}
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {}},
#  'author': 'trends_and_insights_agent',
#  'avg_logprobs': -0.0755239056377876,
#  'content': {'parts': [{'function_call': {'args': {'key': 'target_audience',
#                                                    'value': "['Demographics: "
#                                                             'millennials who '
#                                                             'follow jam bands '
#                                                             'such as '
#                                                             'Widespread Panic '
#                                                             "and Phish.', "
#                                                             "'Psychographics: "
#                                                             'millennials who '
#                                                             'respond '
#                                                             'positively to '
#                                                             'nostalgic '
#                                                             "messages.', "
#                                                             "'Lifestyle or "
#                                                             'profession: '
#                                                             'frequent '
#                                                             'travelers; '
#                                                             'spending most '
#                                                             'income on concert '
#                                                             "experiences.', "
#                                                             "'Hobbies, "
#                                                             'interests, humor: '
#                                                             'music lovers, '
#                                                             'attend lots of '
#                                                             'jam band '
#                                                             "concerts.', "
#                                                             "'Actively "
#                                                             'researching '
#                                                             'concert and music '
#                                                             'festival tickets; '
#                                                             'musical '
#                                                             "instruments.']"},
#                                           'id': 'adk-a019b492-cb63-436a-a113-87f3b14f9725',
#                                           'name': 'memorize'},
#                         'thought_signature': 'CnsB4_H_XumOmo3BjvEsDOjV1p7MOLUOcEQRtsnrqSmBIWrqeMcmAgB0rJBXmfOxEhpUc1-6VQbCB_NpsBuSnGaG96AAqUoj9Pc35SS1GvRF9gF40kaqBFNhoXt26DQ_0YNaoIQ1f5GKFXhlS0zpH_nkwO-sUhcBkirBtDo='}],
#              'role': 'model'},
#  'finish_reason': 'STOP',
#  'id': 'fcfedba4-0508-43ef-8e0a-d553647158a0',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'long_running_tool_ids': [],
#  'model_version': 'gemini-2.5-flash',
#  'timestamp': 1764717939.496154,
#  'usage_metadata': {'cache_tokens_details': [{'modality': 'TEXT',
#                                               'token_count': 2555}],
#                     'cached_content_token_count': 2555,
#                     'candidates_token_count': 82,
#                     'candidates_tokens_details': [{'modality': 'TEXT',
#                                                    'token_count': 82}],
#                     'prompt_token_count': 2648,
#                     'prompt_tokens_details': [{'modality': 'TEXT',
#                                                'token_count': 3184}],
#                     'thoughts_token_count': 24,
#                     'total_token_count': 2754,
#                     'traffic_type': 'ON_DEMAND'}}
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {'target_audience': "['Demographics: millennials "
#                                                 'who follow jam bands such as '
#                                                 "Widespread Panic and Phish.', "
#                                                 "'Psychographics: millennials "
#                                                 'who respond positively to '
#                                                 "nostalgic messages.', "
#                                                 "'Lifestyle or profession: "
#                                                 'frequent travelers; spending '
#                                                 'most income on concert '
#                                                 "experiences.', 'Hobbies, "
#                                                 'interests, humor: music '
#                                                 'lovers, attend lots of jam '
#                                                 "band concerts.', 'Actively "
#                                                 'researching concert and music '
#                                                 'festival tickets; musical '
#                                                 "instruments.']"}},
#  'author': 'trends_and_insights_agent',
#  'content': {'parts': [{'function_response': {'id': 'adk-a019b492-cb63-436a-a113-87f3b14f9725',
#                                               'name': 'memorize',
#                                               'response': {'status': 'Stored '
#                                                                      '"target_audience": '
#                                                                      '"[\'Demographics: '
#                                                                      'millennials '
#                                                                      'who '
#                                                                      'follow '
#                                                                      'jam '
#                                                                      'bands '
#                                                                      'such as '
#                                                                      'Widespread '
#                                                                      'Panic '
#                                                                      'and '
#                                                                      "Phish.', "
#                                                                      "'Psychographics: "
#                                                                      'millennials '
#                                                                      'who '
#                                                                      'respond '
#                                                                      'positively '
#                                                                      'to '
#                                                                      'nostalgic '
#                                                                      "messages.', "
#                                                                      "'Lifestyle "
#                                                                      'or '
#                                                                      'profession: '
#                                                                      'frequent '
#                                                                      'travelers; '
#                                                                      'spending '
#                                                                      'most '
#                                                                      'income '
#                                                                      'on '
#                                                                      'concert '
#                                                                      "experiences.', "
#                                                                      "'Hobbies, "
#                                                                      'interests, '
#                                                                      'humor: '
#                                                                      'music '
#                                                                      'lovers, '
#                                                                      'attend '
#                                                                      'lots of '
#                                                                      'jam band '
#                                                                      "concerts.', "
#                                                                      "'Actively "
#                                                                      'researching '
#                                                                      'concert '
#                                                                      'and '
#                                                                      'music '
#                                                                      'festival '
#                                                                      'tickets; '
#                                                                      'musical '
#                                                                      'instruments.\']"'}}}],
#              'role': 'user'},
#  'id': '33988f4c-dd31-4c3b-81b7-769499a267ad',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'timestamp': 1764717940.99753}
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {}},
#  'author': 'trends_and_insights_agent',
#  'avg_logprobs': -0.09929452159188011,
#  'content': {'parts': [{'function_call': {'args': {'key': 'target_product',
#                                                    'value': 'Pixel 9 '
#                                                             'smartphone'},
#                                           'id': 'adk-3be0275d-0ab5-4b5f-995f-5324d4768248',
#                                           'name': 'memorize'},
#                         'thought_signature': 'CncB4_H_Xu2aTIBYR3YTJyRyXC5jxrIvKLC9g5RJ7a11U-7PbW3EAXlG6qX69GDPGtSnmE60Inl_Yn4o1Q9yLboHSmT7pU9HDeH5JY3w0x-6HEBCsolIXJjoQShRXdrxDCXu5qnEjWxai7_Xx2zGm7mUEOyKAYIAVw=='}],
#              'role': 'model'},
#  'finish_reason': 'STOP',
#  'id': '4ea75e78-32bd-4dd4-a556-e78bf965c4ba',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'long_running_tool_ids': [],
#  'model_version': 'gemini-2.5-flash',
#  'timestamp': 1764717941.000227,
#  'usage_metadata': {'cache_tokens_details': [{'modality': 'TEXT',
#                                               'token_count': 2547}],
#                     'cached_content_token_count': 2547,
#                     'candidates_token_count': 11,
#                     'candidates_tokens_details': [{'modality': 'TEXT',
#                                                    'token_count': 11}],
#                     'prompt_token_count': 2816,
#                     'prompt_tokens_details': [{'modality': 'TEXT',
#                                                'token_count': 3374}],
#                     'thoughts_token_count': 24,
#                     'total_token_count': 2851,
#                     'traffic_type': 'ON_DEMAND'}}
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {'target_product': 'Pixel 9 smartphone'}},
#  'author': 'trends_and_insights_agent',
#  'content': {'parts': [{'function_response': {'id': 'adk-3be0275d-0ab5-4b5f-995f-5324d4768248',
#                                               'name': 'memorize',
#                                               'response': {'status': 'Stored '
#                                                                      '"target_product": '
#                                                                      '"Pixel 9 '
#                                                                      'smartphone"'}}}],
#              'role': 'user'},
#  'id': 'e4f6fcee-da8a-4837-a28b-515987370d01',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'timestamp': 1764717942.230059}
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash, backend: GoogleLLMVariant.VERTEX_AI, stream: False
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {}},
#  'author': 'trends_and_insights_agent',
#  'avg_logprobs': -0.0018916555282854216,
#  'content': {'parts': [{'function_call': {'args': {'key': 'key_selling_points',
#                                                    'value': "['Best Take - "
#                                                             'Group pics, '
#                                                             'perfected. '
#                                                             'Pixel’s Best Take '
#                                                             'combines similar '
#                                                             'photos into one '
#                                                             'fantastic picture '
#                                                             'where everyone '
#                                                             'looks their best. '
#                                                             'AI is able to '
#                                                             'blend multiple '
#                                                             'still images to '
#                                                             'give everyone '
#                                                             "their best look', "
#                                                             '"Night Sight + '
#                                                             'Astrophotography '
#                                                             '- Capture the '
#                                                             'cosmos with '
#                                                             'Pixel’s signature '
#                                                             "'Night Sight' "
#                                                             "feature. 'Night "
#                                                             "Sight' helps "
#                                                             'capture '
#                                                             'everything from '
#                                                             'the city lights '
#                                                             'to starry skies '
#                                                             'in the dark with '
#                                                             'Astrophotography.", '
#                                                             '"Magic Editor - '
#                                                             'Magic Editor with '
#                                                             'Pixel lets you '
#                                                             'use generative AI '
#                                                             'to reimagine your '
#                                                             'photos. Remove '
#                                                             'distractions, '
#                                                             'improve '
#                                                             'background, and '
#                                                             "more. It's an "
#                                                             'intuitive new way '
#                                                             'to edit, so '
#                                                             "you're in control "
#                                                             'of your images, '
#                                                             'whether you want '
#                                                             'to better capture '
#                                                             'the moment or add '
#                                                             'your own creative '
#                                                             'touch. ", \'Call '
#                                                             'Screen - Goodbye, '
#                                                             'spam calls. With '
#                                                             'Call Screen, '
#                                                             'Pixel can now '
#                                                             'detect and filter '
#                                                             'out even more '
#                                                             'spam calls. For '
#                                                             'other calls, it '
#                                                             'can tell you '
#                                                             'who’s calling and '
#                                                             'why before you '
#                                                             'pick up. Detect '
#                                                             'and decline spam '
#                                                             'calls without '
#                                                             'distracting '
#                                                             "you.', 'Live "
#                                                             'Translate - Live '
#                                                             'Translate enables '
#                                                             'real-time '
#                                                             'translation '
#                                                             'without an app '
#                                                             'and without an '
#                                                             'internet '
#                                                             'connection - not '
#                                                             'just text-based '
#                                                             'but also spoken '
#                                                             'words, '
#                                                             'interpreting live '
#                                                             'audio from one '
#                                                             'speaker to '
#                                                             'another. You can '
#                                                             'read text in '
#                                                             'another language '
#                                                             'by pointing the '
#                                                             'camera at a sign '
#                                                             'or a menu, or '
#                                                             'watch a video '
#                                                             'that isn’t in '
#                                                             'your native '
#                                                             'tongue with Live '
#                                                             "Caption. ', 'Real "
#                                                             'Tone - this '
#                                                             'feature '
#                                                             'represents the '
#                                                             'nuances of more '
#                                                             'skin tones '
#                                                             'beautifully, '
#                                                             'authentically, '
#                                                             'and accurately in '
#                                                             'photos and video, '
#                                                             'with improvements '
#                                                             'for low light '
#                                                             'scenarios as '
#                                                             "well.']"},
#                                           'id': 'adk-6921bcf4-a73a-4cdc-bdb5-3a4f6800f6b0',
#                                           'name': 'memorize'},
#                         'thought_signature': 'CnoB4_H_Xg-D3hUPQpgtHuPNEMKxTx2qTaPkYX4-epkKYozvaUk-ExZ7L_13ZxwfJ9OxW7h0RWVe626aB6MUYpb1eRwleF34vfrHMSGdCGo8G7D85hXAsxSjFTUJrWfvebe7IXI3X-Z0jJiLWosLYZAcxf6vPOLnr_KhpQ=='}],
#              'role': 'model'},
#  'finish_reason': 'STOP',
#  'id': '97b56fce-6c93-4f5d-9b59-6a8ddcd5a9cd',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'long_running_tool_ids': [],
#  'model_version': 'gemini-2.5-flash',
#  'timestamp': 1764717942.232412,
#  'usage_metadata': {'candidates_token_count': 321,
#                     'candidates_tokens_details': [{'modality': 'TEXT',
#                                                    'token_count': 321}],
#                     'prompt_token_count': 2842,
#                     'prompt_tokens_details': [{'modality': 'TEXT',
#                                                'token_count': 3422}],
#                     'thoughts_token_count': 26,
#                     'total_token_count': 3189,
#                     'traffic_type': 'ON_DEMAND'}}
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {'key_selling_points': "['Best Take - Group pics, "
#                                                    'perfected. Pixel’s Best '
#                                                    'Take combines similar '
#                                                    'photos into one fantastic '
#                                                    'picture where everyone '
#                                                    'looks their best. AI is '
#                                                    'able to blend multiple '
#                                                    'still images to give '
#                                                    "everyone their best look', "
#                                                    '"Night Sight + '
#                                                    'Astrophotography - Capture '
#                                                    'the cosmos with Pixel’s '
#                                                    "signature 'Night Sight' "
#                                                    "feature. 'Night Sight' "
#                                                    'helps capture everything '
#                                                    'from the city lights to '
#                                                    'starry skies in the dark '
#                                                    'with Astrophotography.", '
#                                                    '"Magic Editor - Magic '
#                                                    'Editor with Pixel lets you '
#                                                    'use generative AI to '
#                                                    'reimagine your photos. '
#                                                    'Remove distractions, '
#                                                    'improve background, and '
#                                                    "more. It's an intuitive "
#                                                    "new way to edit, so you're "
#                                                    'in control of your images, '
#                                                    'whether you want to better '
#                                                    'capture the moment or add '
#                                                    'your own creative touch. '
#                                                    '", \'Call Screen - '
#                                                    'Goodbye, spam calls. With '
#                                                    'Call Screen, Pixel can now '
#                                                    'detect and filter out even '
#                                                    'more spam calls. For other '
#                                                    'calls, it can tell you '
#                                                    'who’s calling and why '
#                                                    'before you pick up. Detect '
#                                                    'and decline spam calls '
#                                                    "without distracting you.', "
#                                                    "'Live Translate - Live "
#                                                    'Translate enables '
#                                                    'real-time translation '
#                                                    'without an app and without '
#                                                    'an internet connection - '
#                                                    'not just text-based but '
#                                                    'also spoken words, '
#                                                    'interpreting live audio '
#                                                    'from one speaker to '
#                                                    'another. You can read text '
#                                                    'in another language by '
#                                                    'pointing the camera at a '
#                                                    'sign or a menu, or watch a '
#                                                    'video that isn’t in your '
#                                                    'native tongue with Live '
#                                                    "Caption. ', 'Real Tone - "
#                                                    'this feature represents '
#                                                    'the nuances of more skin '
#                                                    'tones beautifully, '
#                                                    'authentically, and '
#                                                    'accurately in photos and '
#                                                    'video, with improvements '
#                                                    'for low light scenarios as '
#                                                    "well.']"}},
#  'author': 'trends_and_insights_agent',
#  'content': {'parts': [{'function_response': {'id': 'adk-6921bcf4-a73a-4cdc-bdb5-3a4f6800f6b0',
#                                               'name': 'memorize',
#                                               'response': {'status': 'Stored '
#                                                                      '"key_selling_points": '
#                                                                      '"[\'Best '
#                                                                      'Take - '
#                                                                      'Group '
#                                                                      'pics, '
#                                                                      'perfected. '
#                                                                      'Pixel’s '
#                                                                      'Best '
#                                                                      'Take '
#                                                                      'combines '
#                                                                      'similar '
# ...
#                                                                              '13 '
#                                                                              '| '
#                                                                              'wmur                            '
#                                                                              '|     '
#                                                                              '13 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '14 '
#                                                                              '| '
#                                                                              'black '
#                                                                              'friday '
#                                                                              'cyber '
#                                                                              'monday '
#                                                                              'deals '
#                                                                              '|     '
#                                                                              '14 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '15 '
#                                                                              '| '
#                                                                              'noah '
#                                                                              'hawley                     '
#                                                                              '|     '
#                                                                              '15 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '16 '
#                                                                              '| '
#                                                                              'trump '
#                                                                              'mri                       '
#                                                                              '|     '
#                                                                              '16 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '17 '
#                                                                              '| '
#                                                                              'snowflake                       '
#                                                                              '|     '
#                                                                              '17 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '18 '
#                                                                              '| '
#                                                                              'half '
#                                                                              'life '
#                                                                              '3                     '
#                                                                              '|     '
#                                                                              '18 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '19 '
#                                                                              '| '
#                                                                              'real '
#                                                                              'id                         '
#                                                                              '|     '
#                                                                              '19 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '20 '
#                                                                              '| '
#                                                                              'weather '
#                                                                              'forecast                '
#                                                                              '|     '
#                                                                              '20 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '21 '
#                                                                              '| '
#                                                                              'jimmy '
#                                                                              'sexton                    '
#                                                                              '|     '
#                                                                              '21 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '22 '
#                                                                              '| '
#                                                                              'scarlett '
#                                                                              'johansson              '
#                                                                              '|     '
#                                                                              '22 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '23 '
#                                                                              '| '
#                                                                              'rosa '
#                                                                              'parks                      '
#                                                                              '|     '
#                                                                              '23 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '24 '
#                                                                              '| '
#                                                                              'nick '
#                                                                              'marsh                      '
#                                                                              '|     '
#                                                                              '24 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|\n'
#                                                                              '| '
#                                                                              '25 '
#                                                                              '| '
#                                                                              'brianna '
#                                                                              'aguilera '
#                                                                              'austin         '
#                                                                              '|     '
#                                                                              '25 '
#                                                                              '| '
#                                                                              '2025-12-01     '
#                                                                              '|',
#                                                            'status': 'ok'}}}],
#              'role': 'user'},
#  'id': '1845fb55-2687-4366-979d-5480027af5b0',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'timestamp': 1764717949.379443}
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# {'actions': {'artifact_delta': {},
#              'requested_auth_configs': {},
#              'requested_tool_confirmations': {},
#              'state_delta': {}},
#  'author': 'trends_and_insights_agent',
#  'avg_logprobs': -0.025646062997671273,
#  'content': {'parts': [{'text': 'Here are the top 25 trending Google searches '
#                                 'for the week:\n'
#                                 '\n'
#                                 '| | term | rank | refresh_date |\n'
#                                 '|---:|:--------------------------------|-------:|:---------------|\n'
#                                 '| 1 | toosii | 1 | 2025-12-01 |\n'
#                                 '| 2 | adam thielen | 2 | 2025-12-01 |\n'
#                                 '| 3 | alina habba | 3 | 2025-12-01 |\n'
#                                 '| 4 | rayo vallecano - valencia c. f. | 4 | '
#                                 '2025-12-01 |\n'
#                                 '| 5 | weather channel | 5 | 2025-12-01 |\n'
#                                 '| 6 | christmas | 6 | 2025-12-01 |\n'
#                                 '| 7 | roxie hart chicago | 7 | 2025-12-01 |\n'
#                                 '| 8 | accuweather | 8 | 2025-12-01 |\n'
#                                 '| 9 | modot | 9 | 2025-12-01 |\n'
#                                 '| 10 | sienna miller | 10 | 2025-12-01 |\n'
#                                 '| 11 | k&w cafeteria closing | 11 | '
#                                 '2025-12-01 |\n'
#                                 '| 12 | marty supreme | 12 | 2025-12-01 |\n'
#                                 '| 13 | wmur | 13 | 2025-12-01 |\n'
#                                 '| 14 | black friday cyber monday deals | 14 | '
#                                 '2025-12-01 |\n'
#                                 '| 15 | noah hawley | 15 | 2025-12-01 |\n'
#                                 '| 16 | trump mri | 16 | 2025-12-01 |\n'
#                                 '| 17 | snowflake | 17 | 2025-12-01 |\n'
#                                 '| 18 | half life 3 | 18 | 2025-12-01 |\n'
#                                 '| 19 | real id | 19 | 2025-12-01 |\n'
#                                 '| 20 | weather forecast | 20 | 2025-12-01 |\n'
#                                 '| 21 | jimmy sexton | 21 | 2025-12-01 |\n'
#                                 '| 22 | scarlett johansson | 22 | 2025-12-01 '
#                                 '|\n'
#                                 '| 23 | rosa parks | 23 | 2025-12-01 |\n'
#                                 '| 24 | nick marsh | 24 | 2025-12-01 |\n'
#                                 '| 25 | brianna aguilera austin | 25 | '
#                                 '2025-12-01 |\n'
#                                 '\n'
#                                 "Please select the trending topic you'd like "
#                                 "to proceed with by providing the 'term', "
#                                 "'rank', and 'refresh_date'.",
#                         'thought_signature': 'CtsBAePx_176s5kN1TsgTx9ezgbREF0tMLd9Oi9aAMTf-HNvIRyDIc8A0ex7nz0JexwhhDLeruHEb1lGpJis2OZ5-Jy0Wojp_G1wwCNFL2oO206T6VAcoNljrV-hdlC1tRWMa4cvElGhs0QD8QtAZxc9_qKXSf4swd6uEb68qiSn6d6UPmaIIy2YwV0M7kBFPlMY9qEJjLPM8sO0nOU-Kv2ttnwEKDA8YzVCy0qYOWuFmVkGDJhSkNJyI2-Hui78Z1Jqht0yKAGckx5obcZuMlbLAmHsf_QdvjDi3cB8'}],
#              'role': 'model'},
#  'finish_reason': 'STOP',
#  'id': '90235491-c5a9-4bc8-b741-256da12696ad',
#  'invocation_id': 'e-d7353edd-7a4a-4a97-b34c-d7c7d7bfa079',
#  'model_version': 'gemini-2.5-flash',
#  'timestamp': 1764717949.382996,
#  'usage_metadata': {'cache_tokens_details': [{'modality': 'TEXT',
#                                               'token_count': 3506}],
#                     'cached_content_token_count': 3506,
#                     'candidates_token_count': 702,
#                     'candidates_tokens_details': [{'modality': 'TEXT',
#                                                    'token_count': 702}],
#                     'prompt_token_count': 4216,
#                     'prompt_tokens_details': [{'modality': 'TEXT',
#                                                'token_count': 4903}],
#                     'thoughts_token_count': 41,
#                     'total_token_count': 4959,
#                     'traffic_type': 'ON_DEMAND'}}

# %%
followup_prompt = "Create images from these great ideas!"
stream_agent(my_agent, followup_prompt, session)

# %% [markdown]
# ## 4. Deploy to Vertex AI Agent Engine
# To call and manage agents in production, deploy the agent to Vertex AI Agent Engine.
#
# **Important - run `poetry build` to package the agent**

# %%
! poetry build --format=wheel --output=deployment
# Out:
# Building trends_and_insights_agent (0.1.0)
# Building wheel
#   - Building wheel
#   - Built trends_and_insights_agent-0.1.0-py3-none-any.whl

# %% [markdown]
# #### Initialize the Vertex client, then create a `remote_agent` that is deployed to Vertex
#
# This also takes the packaged agent code. This is required for more complex agents that have nested dependencies and require packaging
#
# Also, before running - be sure to give Secret Manager access to the Agent Engine service account. This can simply be done by running `. setup_ae_sm_access.sh`.
#
# The code can also be ran as follows (relative to repo root):
#
# ```bash
# source trends_and_insights_agent/.env
#
# export RE_SA="service-${GOOGLE_CLOUD_PROJECT_NUMBER}@gcp-sa-aiplatform-re.iam.gserviceaccount.com"
# gcloud secrets add-iam-policy-binding "projects/$GOOGLE_CLOUD_PROJECT/secrets/$YT_SECRET_MNGR_NAME" \
#   --member="serviceAccount:$RE_SA" \
#   --role="roles/secretmanager.secretAccessor"
# ```

# %%
from vertexai import agent_engines  # optional cleanup

for agent in agent_engines.list():
    agent.delete(force=True)

# %%
import vertexai
from vertexai import agent_engines

GOOGLE_CLOUD_PROJECT = os.getenv("GOOGLE_CLOUD_PROJECT")
BUCKET = os.getenv("BUCKET")

vertexai.init(
    project=GOOGLE_CLOUD_PROJECT,
    location="us-central1",
    staging_bucket=BUCKET,
)

remote_agent = agent_engines.create(
    agent_engine=my_agent,
    display_name="trends-and-insights",
    description="You are a helpful AI assistant, part of a multi-agent system designed for advanced web research and ad creative generation.",
    requirements=[
        "deployment/trends_and_insights_agent-0.1.0-py3-none-any.whl",
        "db-dtypes",
        "tabulate",
    ],
    extra_packages=[
        "deployment/trends_and_insights_agent-0.1.0-py3-none-any.whl",
        "installation_scripts/install_opencv.sh",
        "installation_scripts/install_ffmpeg.sh",
    ],
    env_vars=env_vars,
    build_options={
        "installation": [
            "installation_scripts/install_opencv.sh",
            "installation_scripts/install_ffmpeg.sh",
        ]
    },
)
# Out:
# INFO:vertexai.agent_engines:Identified the following requirements: {'google-cloud-aiplatform': '1.128.0', 'cloudpickle': '3.1.1', 'pydantic': '2.11.7'}
# WARNING:vertexai.agent_engines:The following requirements are missing: {'google-cloud-aiplatform', 'cloudpickle', 'pydantic'}
# INFO:vertexai.agent_engines:The following requirements are appended: {'pydantic==2.11.7', 'cloudpickle==3.1.1'}
# INFO:vertexai.agent_engines:The final list of requirements: ['deployment/trends_and_insights_agent-0.1.0-py3-none-any.whl', 'db-dtypes', 'tabulate', 'pydantic==2.11.7', 'cloudpickle==3.1.1']
# INFO:vertexai.agent_engines:Using bucket zghost-media-center
# INFO:vertexai.agent_engines:Wrote to gs://zghost-media-center/agent_engine/agent_engine.pkl
# INFO:vertexai.agent_engines:Writing to gs://zghost-media-center/agent_engine/requirements.txt
# INFO:vertexai.agent_engines:Creating in-memory tarfile of extra_packages
# INFO:vertexai.agent_engines:Writing to gs://zghost-media-center/agent_engine/dependencies.tar.gz
# WARNING:vertexai.agent_engines:Bidi stream API mode is not supported yet in Vertex SDK, please use the GenAI SDK instead. Skipping method bidi_stream_query.
# INFO:vertexai.agent_engines:Creating AgentEngine
# INFO:vertexai.agent_engines:Create AgentEngine backing LRO: projects/679926387543/locations/us-central1/reasoningEngines/1065923746570698752/operations/6662862120100560896
# INFO:vertexai.agent_engines:View progress and logs at https://console.cloud.google.com/logs/query?project=wortz-project-352116
# INFO:vertexai.agent_engines:AgentEngine created. Resource name: projects/679926387543/locations/us-central1/reasoningEngines/1065923746570698752
# INFO:vertexai.agent_engines:To use this AgentEngine in another session:
# INFO:vertexai.agent_engines:agent_engine = vertexai.agent_engines.get('projects/679926387543/locations/us-central1/reasoningEngines/1065923746570698752')

# %% [markdown]
# ### Save the agent engine resource name
#
# This can be used by the command to deploy it to Agentspace
#
# ```bash
# agent_engine = vertexai.agent_engines.get('projects/679926387543/locations/us-central1/reasoningEngines/1093257605637210112')
# ```
#
# ## 5. Try it remotely

# %%
online_session = await remote_agent.async_create_session(user_id="jwortz")
online_session
# Out:
# {'userId': 'jwortz',
#  'id': '3913363368760573952',
#  'lastUpdateTime': 1764719417.755459,
#  'events': [],
#  'state': {},
#  'appName': '1065923746570698752'}

# %% [markdown]
# #### Same idea above applies to remote agents

# %%
first_prompt = f"Hello"

stream_agent(remote_agent, first_prompt, online_session)

# %% [markdown]
# # 6. Optional Cleanup

# %%
remote_agent.delete(force=True)
